# %%
from main import main

# %%
temp = main()
temp
# Out:
#    direction  speed  timepoint  cloudcover  lifted_index prec_type  \
# 0          S      2          3           9            15      none
# 1         SW      2          6           9            15      none
# 2          S      2          9           9            15      none
# 3          S      2         12           9            15      none
# 4          S      2         15           9            15      none
# ..       ...    ...        ...         ...           ...       ...
# 59        SW      2        180           9             6      snow
# 60         W      2        183           9            10      snow
# 61         W      2        186           9            10      snow
# 62        NE      2        189           8            10      snow
# 63         N      2        192           5            10      snow
#
#     prec_amount  temp2m rh2m         weather          datetime        Date  \
# 0             1      -3  88%       cloudyday  2023-02-01 13:00  2023-02-01
# ...

# %%
from visual import visual

flag = visual()
flag
# Out:
# alt.LayerChart(...)

# %%
import pandas as pd
df = pd.read_excel('convertcsv.xlsx')
df.head()
# Out:
#    timepoint  cloudcover  lifted_index prec_type  prec_amount  temp2m rh2m  \
# 0          3           9            15      none            1      -3  88%
# 1          6           9            15      none            1      -2  91%
# 2          9           9            15      none            1      -4  95%
# 3         12           9            15      none            1      -5  90%
# 4         15           9            15      none            1      -7  94%
#
#   wind10m/direction  wind10m/speed      weather
# 0                 S              2    cloudyday
# 1                SW              2    cloudyday
# 2                 S              2  cloudynight
# 3                 S              2  cloudynight
# 4                 S              2  cloudynight
